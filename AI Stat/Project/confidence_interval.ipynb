# %% [markdown]
# med individual

# %%
base_scores = [0.583333, 0.583333, 0.416667, 0.416667, 0.333333, 0.166667, 0.5, 0.5, 0.333333, 0.333333, 0.333333, 0.666667, 0.833333, 0.5]
classtree_scores = [0.75, 0.583333, 0.666667, 0.666667, 0.583333, 0.5, 0.583333, 0.5, 0.666667, 0.916667, 0.916667, 0.75, 1.0, 0.583333]
knn_scores = [0.75, 0.666667, 0.666667, 0.666667, 0.583333, 0.5, 0.583333, 0.833333, 0.666667, 0.916667, 0.916667, 0.75, 1.0, 0.583333]
logreg_scores = [0.75, 0.666667, 0.666667, 0.666667, 0.583333, 0.5, 0.583333, 0.833333, 0.666667, 0.916667, 0.916667, 0.75, 1.0, 0.583333]
ann_scores = [0.75, 0.666667, 0.666667, 0.666667, 0.583333, 0.5, 0.583333, 0.833333, 0.666667, 0.916667, 0.916667, 0.75, 1.0, 0.583333]

# %%
from math import sqrt
import statistics
import matplotlib.pyplot as plt

def plot_confidence_interval(x, values, z=1.96, color='#2187bb', horizontal_line_width=0.25):
    mean = statistics.mean(values)
    stdev = statistics.stdev(values)
    confidence_interval = z * stdev / sqrt(len(values))

    left = x - horizontal_line_width / 2
    top = mean - confidence_interval
    right = x + horizontal_line_width / 2
    bottom = mean + confidence_interval
    plt.plot([x, x], [top, bottom], color=color)
    plt.plot([left, right], [top, top], color=color)
    plt.plot([left, right], [bottom, bottom], color=color)
    plt.plot(x, mean, 'o', color='#f44336')

    return mean, confidence_interval

plt.xticks([1, 2, 3, 4, 5], ['Baseline', 'KNN', 'ANN', 'LogReg', 'Classification Tree'])
plt.title('Confidence Interval for predicting puzzler')
plot_confidence_interval(1, base_scores)
plot_confidence_interval(2, knn_scores)
plot_confidence_interval(3, ann_scores)
plot_confidence_interval(4, logreg_scores)
plot_confidence_interval(5, classtree_scores)
plt.ylabel('Accuracy')
plt.show()

# %% [markdown]
# med individual & puzzler

# %%
base_scores = [0.416667, 0.833333, 0.416667, 0.416667, 0.5, 0.416667, 0.583333, 0.75, 0.75, 0.583333, 0.416667, 0.583333, 0.416667, 0.583333]
classtree_scores = [0.75, 0.583333, 0.666667, 0.666667, 0.583333, 0.5, 0.583333, 0.5, 0.666667, 0.916667, 0.916667, 0.75, 1.0, 0.5]
knn_scores = [0.75, 0.666667, 0.666667, 0.666667, 0.583333, 0.5, 0.583333, 0.583333, 0.666667, 0.916667, 0.916667, 0.75, 1.0, 0.583333]
logreg_scores = [0.75, 0.666667, 0.666667, 0.666667, 0.583333, 0.5, 0.583333, 0.583333, 0.666667, 0.916667, 0.916667, 0.75, 1.0, 0.583333]
ann_scores = [0.75, 0.666667, 0.666667, 0.666667, 0.583333, 0.5, 0.583333, 0.583333, 0.666667, 0.916667, 0.916667, 0.75, 1.0, 0.583333]

# %%
plt.xticks([1, 2, 3, 4, 5], ['Baseline', 'KNN', 'ANN', 'LogReg', 'Classification Tree'])
plt.title('Confidence Interval for predicting puzzler')
plot_confidence_interval(1, base_scores)
plot_confidence_interval(2, knn_scores)
plot_confidence_interval(3, ann_scores)
plot_confidence_interval(4, logreg_scores)
plot_confidence_interval(5, classtree_scores)
plt.ylabel('Accuracy')
plt.show()

# %% [markdown]
# udelukkende individuals

# %%
base_scores = [0.75, 0.666667, 0.666667, 0.666667, 0.583333, 0.5, 0.583333, 0.833333, 0.666667, 0.916667, 0.916667, 0.75, 1.0, 0.583333]
classtree_scores = [0.75, 0.583333, 0.666667, 0.666667, 0.583333, 0.5, 0.583333, 0.5, 0.666667, 0.916667, 0.916667, 0.75, 1.0, 0.5]
knn_scores = [0.75, 0.666667, 0.666667, 0.666667, 0.583333, 0.5, 0.583333, 0.583333, 0.666667, 0.916667, 0.916667, 0.75, 1.0, 0.583333]
logreg_scores = [0.75, 0.666667, 0.666667, 0.666667, 0.583333, 0.5, 0.583333, 0.833333, 0.666667, 0.916667, 0.916667, 0.75, 1.0, 0.583333]
ann_scores = [0.75, 0.666667, 0.666667, 0.666667, 0.583333, 0.5, 0.583333, 0.833333, 0.666667, 0.916667, 0.916667, 0.75, 1.0, 0.583333]

# %%
plt.xticks([1, 2, 3, 4, 5], ['Baseline', 'KNN', 'ANN', 'LogReg', 'Classification Tree'])
plt.title('Confidence Interval for predicting frustration (HIGH/LOW) from individual')
plot_confidence_interval(1, base_scores)
plot_confidence_interval(2, knn_scores)
plot_confidence_interval(3, ann_scores)
plot_confidence_interval(4, logreg_scores)
plot_confidence_interval(5, classtree_scores)
plt.ylabel('Accuracy')
plt.show()

# %% [markdown]
# random test sets

# %%
base_scores = [0.727273, 0.636364, 0.8, 0.85, 0.769231, 0.631579, 0.5, 0.5, 0.75, 0.9, 0.705882, 0.888889, 0.75, 0.333333]
classtree_scores = [0.818182, 0.636364, 0.8, 0.9, 0.692308, 0.578947, 0.5, 0.5, 0.75, 0.9, 0.705882, 0.888889, 0.75, 0.333333]
knn_scores = [0.727273, 0.636364, 0.8, 0.85, 0.769231, 0.631579, 0.5, 0.5, 0.75, 0.9, 0.705882, 0.666667, 0.75, 0.333333]
logreg_scores = [0.727273, 0.636364, 0.8, 0.85, 0.769231, 0.631579, 0.5, 0.5, 0.75, 0.9, 0.705882, 0.888889, 0.75, 0.333333]
ann_scores = [0.727273, 0.636364, 0.733333, 0.8, 0.615385, 0.631579, 0.5, 0.5, 0.666667, 0.9, 0.647059, 0.555556, 0.75, 0.333333]

# %%
plt.xticks([1, 2, 3, 4, 5], ['Baseline', 'KNN', 'ANN', 'LogReg', 'Classification Tree'])
plt.title('Confidence Interval for predicting frustration (HIGH/LOW) from random split')
plot_confidence_interval(1, base_scores)
plot_confidence_interval(2, knn_scores)
plot_confidence_interval(3, ann_scores)
plot_confidence_interval(4, logreg_scores)
plot_confidence_interval(5, classtree_scores)
plt.ylabel('Accuracy')
plt.show()

# %% [markdown]
# with relatives, split train test based on individuals

# %%
base_scores = [0.75, 0.666667, 0.666667, 0.666667, 0.583333, 0.5, 0.583333, 0.833333, 0.666667, 0.916667, 0.916667, 0.75, 1.0, 0.583333]
classtree_scores = [0.666667, 0.666667, 0.666667, 0.416667, 0.583333, 0.5, 0.5, 0.833333, 0.666667, 0.916667, 0.916667, 0.75, 1.0, 0.583333]
knn_scores = [0.75, 0.666667, 0.666667, 0.666667, 0.583333, 0.5, 0.583333, 0.833333, 0.666667, 0.916667, 0.916667, 0.666667, 1.0, 0.583333]
logreg_scores = [0.75, 0.666667, 0.666667, 0.666667, 0.583333, 0.5, 0.583333, 0.833333, 0.666667, 0.916667, 0.916667, 0.75, 1.0, 0.583333]
ann_scores = [0.75, 0.666667, 0.666667, 0.666667, 0.583333, 0.5, 0.583333, 0.833333, 0.666667, 0.916667, 0.916667, 0.75, 1.0, 0.583333]

# %%
plt.xticks([1, 2, 3, 4, 5], ['Baseline', 'KNN', 'ANN', 'LogReg', 'Classification Tree'])
plt.title('Confidence Interval for predicting frustration (HIGH/LOW) from individual')
plot_confidence_interval(1, base_scores)
plot_confidence_interval(2, knn_scores)
plot_confidence_interval(3, ann_scores)
plot_confidence_interval(4, logreg_scores)
plot_confidence_interval(5, classtree_scores)
plt.ylabel('Accuracy')
plt.show()

# %% [markdown]
# with relatives, split train test randomly

# %%
base_scores = [0.8, 0.5, 0.571429, 0.666667, 0.818182, 0.888889, 0.714286, 0.777778, 0.714286, 0.714286, 0.75, 0.714286, 0.777778, 0.769231]
classtree_scores = [0.733333, 0.5, 0.571429, 0.666667, 0.727273, 0.888889, 0.714286, 0.777778, 0.5, 0.642857, 0.75, 0.714286, 0.888889, 0.769231]
knn_scores = [0.8, 0.5, 0.571429, 0.6, 0.818182, 0.888889, 0.714286, 0.777778, 0.714286, 0.714286, 0.75, 0.714286, 0.777778, 0.769231]
logreg_scores = [0.8, 0.5, 0.571429, 0.666667, 0.818182, 0.888889, 0.714286, 0.777778, 0.714286, 0.714286, 0.666667, 0.714286, 0.777778, 0.769231]
ann_scores = [0.8, 0.5, 0.571429, 0.666667, 0.818182, 0.888889, 0.714286, 0.777778, 0.714286, 0.714286, 0.75, 0.714286, 0.777778, 0.769231]

# %%
plt.xticks([1, 2, 3, 4, 5], ['Baseline', 'KNN', 'ANN', 'LogReg', 'Classification Tree'])
plt.title('Confidence Interval for predicting frustration (HIGH/LOW) from individual')
plot_confidence_interval(1, base_scores)
plot_confidence_interval(2, knn_scores)
plot_confidence_interval(3, ann_scores)
plot_confidence_interval(4, logreg_scores)
plot_confidence_interval(5, classtree_scores)
plt.ylabel('Accuracy')
plt.show()

# %% [markdown]
# Puzzler on significant featureS, random split

# %%
base_scores = [0.45, 0.357143, 0.222222, 0.2, 0.466667, 0.461538, 0.5, 0.454545, 0.466667, 0.4, 0.5, 0.333333, 0.230769, 0.4]
classtree_scores = [0.55, 0.428571, 0.444444, 0.8, 0.666667, 0.769231, 0.75, 0.545455, 0.6, 0.7, 0.375, 0.583333, 0.461538, 0.6]
knn_scores = [0.4, 0.714286, 0.555556, 0.5, 0.666667, 0.538462, 0.75, 0.363636, 0.666667, 0.7, 0.5, 0.583333, 0.538462, 0.5]
logreg_scores = [0.45, 0.428571, 0.222222, 0.2, 0.466667, 0.461538, 0.75, 0.363636, 0.466667, 0.4, 0.375, 0.5, 0.230769, 0.4]
ann_scores = [0.45, 0.357143, 0.333333, 0.2, 0.466667, 0.384615, 0.75, 0.363636, 0.4, 0.7, 0.375, 0.5, 0.307692, 0.6]

# %%
plt.xticks([1, 2, 3, 4, 5], ['Baseline', 'KNN', 'ANN', 'LogReg', 'Classification Tree'])
plt.title('Confidence Interval for predicting frustration (HIGH/LOW) from individual')
plot_confidence_interval(1, base_scores)
plot_confidence_interval(2, knn_scores)
plot_confidence_interval(3, ann_scores)
plot_confidence_interval(4, logreg_scores)
plot_confidence_interval(5, classtree_scores)
plt.ylabel('Accuracy')
plt.show()

# %% [markdown]
# Puzzler on significant, individuals split

# %%
base_scores = [0.333333, 0.5, 0.333333, 0.5, 0.5, 0.666667, 0.5, 0.666667, 0.5, 0.666667, 0.333333, 0.666667, 0.5, 0.333333]
classtree_scores = [0.0, 0.75, 1.0, 0.25, 0.75, 0.166667, 0.166667, 0.583333, 0.583333, 0.416667, 0.25, 0.0, 0.833333, 0.5]
knn_scores = [0.0, 0.666667, 0.833333, 0.25, 0.666667, 0.416667, 0.333333, 0.583333, 0.416667, 0.5, 0.166667, 0.083333, 0.333333, 0.5]
logreg_scores = [0.25, 0.833333, 1.0, 0.333333, 0.75, 0.166667, 0.5, 0.416667, 0.583333, 0.166667, 0.083333, 0.083333, 0.916667, 1.0]
ann_scores = [0.083333, 0.833333, 1.0, 0.25, 0.75, 0.166667, 0.333333, 0.416667, 0.583333, 0.333333, 0.0, 0.0, 0.833333, 1.0]

# %%
plt.xticks([1, 2, 3, 4, 5], ['Baseline', 'KNN', 'ANN', 'LogReg', 'Classification Tree'])
plt.title('Confidence Interval for predicting frustration (HIGH/LOW) from individual')
plot_confidence_interval(1, base_scores)
plot_confidence_interval(2, knn_scores)
plot_confidence_interval(3, ann_scores)
plot_confidence_interval(4, logreg_scores)
plot_confidence_interval(5, classtree_scores)
plt.ylabel('Accuracy')
plt.show()

# %% [markdown]
# Puzzler, random split, random baseline, based on 3 features

# %%
base_scores = [0.4375, 0.615385, 0.307692, 0.428571, 0.416667, 0.6, 0.375, 0.5, 0.6, 0.555556, 0.555556, 0.333333, 0.9, 0.333333]
classtree_scores = [0.375, 0.615385, 0.615385, 0.5, 0.5, 0.533333, 0.375, 0.625, 0.6, 0.777778, 0.444444, 0.583333, 0.4, 0.333333]
knn_scores = [0.375, 0.692308, 0.769231, 0.642857, 0.5, 0.533333, 0.625, 0.5625, 0.6, 0.333333, 0.444444, 0.5, 0.5, 0.5]
logreg_scores = [0.625, 0.538462, 0.692308, 0.642857, 0.333333, 0.6, 0.625, 0.5625, 0.6, 0.444444, 0.777778, 0.583333, 0.6, 0.5]
ann_scores = [0.625, 0.615385, 0.615385, 0.714286, 0.5, 0.6, 0.5, 0.5625, 0.533333, 0.666667, 0.777778, 0.583333, 0.6, 0.5]

# %%
plt.xticks([1, 2, 3, 4, 5], ['Baseline', 'KNN', 'ANN', 'LogReg', 'Classification Tree'])
plt.title('Confidence Interval for predicting frustration (HIGH/LOW) from individual')
plot_confidence_interval(1, base_scores)
plot_confidence_interval(2, knn_scores)
plot_confidence_interval(3, ann_scores)
plot_confidence_interval(4, logreg_scores)
plot_confidence_interval(5, classtree_scores)
plt.ylabel('Accuracy')
plt.show()

# %% [markdown]
# ------

# %%
import numpy as np
z = 1.96
values = np.array([0.25, 0.333333, 0.25, 0.083333, 0.166667, 0.166667, 0.0, 0.25, 0.166667, 0.25, 0.333333, 0.5, 0.833333, 0.166667])

mean = statistics.mean(values)
stdev = statistics.stdev(values)
confidence_interval = z * stdev / sqrt(len(values))
top = mean + confidence_interval
bottom = mean - confidence_interval
bottom, top
# Out:
# (0.16206249049515042, 0.3736517952191353)

# %%
import matplotlib.pyplot as plt
plt.hist(values)
# Out:
# (array([2., 0., 4., 6., 0., 0., 1., 0., 0., 1.]),
#  array([0.       , 0.0833333, 0.1666666, 0.2499999, 0.3333332, 0.4166665,
#         0.4999998, 0.5833331, 0.6666664, 0.7499997, 0.833333 ]),
#  <BarContainer object of 10 artists>)
